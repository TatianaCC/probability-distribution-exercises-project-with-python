# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# ## For normal distribution

# %%
# TODO
# For normal distribution
from scipy.stats import norm
def dnorm(x, d_mean, d_std):
    """
    Calculates probability density function arround x
    """
    result = norm.pdf(x, loc=d_mean, scale=d_std)

    return result

def pnorm(x, d_mean, d_std):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x, loc=d_mean, scale=d_std)

    return result

def qnorm(q, d_mean, d_std):
    """
    The percentile corresponding to the cumulative probability q in a normal distribution with specified mean (loc) and standard deviation (scale)
    """
    result = norm.ppf(q, loc=d_mean, scale=d_std)

    return result

def rnorm(d_mean, d_std, num):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc=d_mean, scale=d_std, size=num, random_state=None)

    return result

# %%
# Normal(10, 0.2) distribution where d_mean = 10 is the mean and d_std = 0.2 is the standard deviation
import numpy as np
np.random.seed(42)

d_mean = 10
d_std = 0.2

print(f"Probability that a Normal(10, 0.2) takes the value 2: {dnorm(2, d_mean, d_std)}")
print(f"Probability that a Normal(10, 0.2) will take a value less than 2: {pnorm(2, d_mean, d_std)}")
print(f"Which value of a Normal(10, 0.2) has a cumulative probability of 0.9? {qnorm(0.9, d_mean, d_std)}")
print(f"Generate 2000 random values from a Normal(10, 0.2) distribution: {rnorm(d_mean, d_std, num=2000)}")
# Out:
# Probability that a Normal(10, 0.2) takes the value 2: 0.0
# Probability that a Normal(10, 0.2) will take a value less than 2: 0.0
# Which value of a Normal(10, 0.2) has a cumulative probability of 0.9? 10.25631031310892
# Generate 2000 random values from a Normal(10, 0.2) distribution: [10.09934283  9.97234714 10.12953771 ...  9.82362507  9.96738661
#   9.85101947]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

d_mean = 10
d_std = 5
data = np.arange(-30, 30, 0.01)

pmf = dnorm(data, d_mean, d_std)
cdf = pnorm(data, d_mean, d_std)
ppf = qnorm(data, d_mean, d_std)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

ax1.plot(data, pmf, "r-")
ax2.plot(data, cdf, "b-")
ax3.plot(ppf, data, "g-")

plt.tight_layout()

plt.show()

# %% [markdown]
# ## For uniform distribution

# %%
from scipy.stats import uniform
def duni(x, d_mean, d_std):
    """
    Calculates probability density function arround x
    """
    result = uniform.pdf(x, loc=d_mean, scale=d_std)

    return result

def puni(x, d_mean, d_std):
    """
    Calculates the cumulative of the uniform distribution
    """
    result = uniform.cdf(x, loc=d_mean, scale=d_std)

    return result

def quni(q, d_mean, d_std):
    """
    The percentile corresponding to the cumulative probability q in a uniform distribution with specified mean (loc) and standard deviation (scale)
    """
    result = uniform.ppf(q, loc=d_mean, scale=d_std)

    return result

def runi(d_mean, d_std, num):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(loc=d_mean, scale=d_std, size=num, random_state=None)

    return result

# %%
# Uniform(10, 0.2) distribution where d_mean = 10 is the mean and d_std = 0.2 is the standard deviation
import numpy as np
np.random.seed(42)

d_mean = 10
d_std = 0.2

print(f"Probability that a Uniform (10, 0.2) takes the value 2: {duni(2, d_mean, d_std)}")
print(f"Probability that a Uniform(10, 0.2) will take a value less than 2: {puni(2, d_mean, d_std)}")
print(f"Which value of a Uniform(10, 0.2) has a cumulative probability of 0.9? {quni(0.9, d_mean, d_std)}")
print(f"Generate 2000 random values from a Normal(10, 0.2) distribution: {runi(d_mean, d_std, num=2000)}")
# Out:
# Probability that a Uniform (10, 0.2) takes the value 2: 0.0
# Probability that a Uniform(10, 0.2) will take a value less than 2: 0.0
# Which value of a Uniform(10, 0.2) has a cumulative probability of 0.9? 10.18
# Generate 2000 random values from a Normal(10, 0.2) distribution: [10.07490802 10.19014286 10.14639879 ... 10.0137916  10.01141094
#  10.05643741]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

d_mean = 10
d_std = 5
data = np.arange(-30, 30, 0.01)

pmf = duni(data, d_mean, d_std)
cdf = puni(data, d_mean, d_std)
ppf = quni(data, d_mean, d_std)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

ax1.plot(data, pmf, "r-")
ax2.plot(data, cdf, "b-")
ax3.plot(ppf, data, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
